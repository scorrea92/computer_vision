# %%
# !nvidia-smi
# Out:
# Wed May 16 17:43:42 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.111                Driver Version: 384.111                   |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX TIT...  Off  | 00000000:05:00.0 Off |                  N/A |
# | 22%   48C    P8    16W / 250W |  11721MiB / 12205MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0      4199      C   ...e/secorec/anaconda3/envs/env/bin/python 11710MiB |
# +-----------------------------------------------------------------------------+

# %%
# -*- coding: utf-8 -*-
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Lambda
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization as BN
from keras.layers import GaussianNoise as GN
from keras.optimizers import SGD, Adam, RMSprop
from keras.models import Model
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from keras.callbacks import LearningRateScheduler as LRS
from keras.preprocessing.image import ImageDataGenerator


batch_size = 32
num_classes = 20
epochs = 50

#### LOAD AND TRANSFORM

# ## Download: ONLY ONCE!
# !wget https://www.dropbox.com/s/kdhn10jwj99xkv7/data.tgz
# !tar xvzf data.tgz
# #####


# Load 
x_train = np.load('x_train.npy')
x_test = np.load('x_test.npy')

y_train = np.load('y_train.npy')
y_test = np.load('y_test.npy')

# Stats
print(x_train.shape)
print(y_train.shape)

print(x_test.shape)
print(y_test.shape)

## View some images
plt.imshow(x_train[2,:,:,: ] )
plt.show()


## Transforms
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

y_train = y_train.astype('float32')
y_test = y_test.astype('float32')


x_train /= 255
x_test /= 255


## Labels
y_train=y_train-1

y_test=y_test-1

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# (791, 250, 250, 3)
# (791,)
# (784, 250, 250, 3)
# (784,)

# %%
from keras.applications.vgg16 import VGG16
from keras.callbacks import ModelCheckpoint

# load the model
model1 = VGG16(weights='imagenet', include_top=False, input_shape=x_train.shape[1:])

#############################
###      BILINEAR        ####
#############################

for layer in model1.layers:
    layer.trainable = False

def outer_product(x):
  phi_I = tf.einsum('ijkm,ijkn->imn',x[0],x[1])		# Einstein Notation  [batch,1,1,depth] x [batch,1,1,depth] -> [batch,depth,depth]
  phi_I = tf.reshape(phi_I,[-1,512*512])	        # Reshape from [batch_size,depth,depth] to [batch_size, depth*depth]
  phi_I = tf.divide(phi_I,31*31)								  # Divide by feature map size [sizexsize]

  y_ssqrt = tf.multiply(tf.sign(phi_I),tf.sqrt(tf.abs(phi_I)+1e-12))		# Take signed square root of phi_I
  z_l2 = tf.nn.l2_normalize(y_ssqrt, dim=1)								              # Apply l2 normalization
  return z_l2



conv=model1.get_layer('block5_conv3') # block5_conv3
d1=Dropout(0.5)(conv.output)
d2=Dropout(0.5)(conv.output)

x = Lambda(outer_product, name='outer_product')([d1,d2])

predictions=Dense(num_classes, activation='softmax', name='predictions')(x)

model = Model(inputs=model1.input, outputs=predictions)


# DEFINE A LEARNING RATE SCHEDULER
def scheduler(epoch):
    if epoch < 25:
        return 0.0001
    elif epoch < 50:
        return 0.00001
    else:
        return 0.000001

set_lr = LRS(scheduler)


## DATAGEN
datagen = ImageDataGenerator(
  width_shift_range=0.2,
  height_shift_range=0.2,
  rotation_range=20,
  zoom_range=[1.0,1.2],
  horizontal_flip=True)


## OPTIM AND COMPILE use Adam Rsmprop
opt = SGD(lr=0.001, decay=1e-6)
rms = RMSprop(lr=0.0001, rho=0.9, epsilon=None, decay=0.0)
adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-6, amsgrad=False)

model.compile(loss='categorical_crossentropy',
              optimizer=rms,
              metrics=['accuracy'])
    
  
model.summary()

checkpoint_path = "Wehigts.hdf5"
checkpointer = ModelCheckpoint(filepath=checkpoint_path, verbose=1, save_best_only=True)

## TRAINING with DA and LRA
history=model.fit_generator(datagen.flow(x_train, y_train,batch_size=batch_size),
                            steps_per_epoch=len(x_train) / batch_size, 
                            epochs=epochs,
                            validation_data=(x_test, y_test),
                            callbacks=[checkpointer],
                            verbose=1)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           (None, 250, 250, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 250, 250, 64) 1792        input_14[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 250, 250, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 125, 125, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 125, 125, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 125, 125, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 62, 62, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 62, 62, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 62, 62, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 62, 62, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 31, 31, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 31, 31, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 31, 31, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 31, 31, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 15, 15, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 15, 15, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 15, 15, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 15, 15, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 15, 15, 512)  0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 15, 15, 512)  0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# outer_product (Lambda)          (None, 262144)       0           dropout_27[0][0]
#                                                                  dropout_28[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 20)           5242900     outer_product[0][0]
# ==================================================================================================
# Total params: 19,957,588
# Trainable params: 5,242,900
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________
# Epoch 1/50
# 25/24 [==============================] - 15s 604ms/step - loss: 2.9934 - acc: 0.0567 - val_loss: 2.9755 - val_acc: 0.0765
#
# Epoch 00001: val_loss improved from inf to 2.97552, saving model to Wehigts.hdf5
# Epoch 2/50
# 25/24 [==============================] - 11s 423ms/step - loss: 2.9733 - acc: 0.1010 - val_loss: 2.9626 - val_acc: 0.1250
#
# Epoch 00002: val_loss improved from 2.97552 to 2.96260, saving model to Wehigts.hdf5
# Epoch 3/50
# 25/24 [==============================] - 11s 424ms/step - loss: 2.9603 - acc: 0.1585 - val_loss: 2.9508 - val_acc: 0.1441
#
# Epoch 00003: val_loss improved from 2.96260 to 2.95080, saving model to Wehigts.hdf5
# Epoch 4/50
# 25/24 [==============================] - 11s 424ms/step - loss: 2.9453 - acc: 0.1677 - val_loss: 2.9393 - val_acc: 0.1569
#
# Epoch 00004: val_loss improved from 2.95080 to 2.93933, saving model to Wehigts.hdf5
# Epoch 5/50
# 25/24 [==============================] - 11s 424ms/step - loss: 2.9334 - acc: 0.1749 - val_loss: 2.9284 - val_acc: 0.1492
#
# Epoch 00005: val_loss improved from 2.93933 to 2.92838, saving model to Wehigts.hdf5
# Epoch 6/50
# 25/24 [==============================] - 11s 423ms/step - loss: 2.9219 - acc: 0.1715 - val_loss: 2.9176 - val_acc: 0.1849
#
# Epoch 00006: val_loss improved from 2.92838 to 2.91763, saving model to Wehigts.hdf5
# Epoch 7/50
# 25/24 [==============================] - 11s 436ms/step - loss: 2.9089 - acc: 0.2040 - val_loss: 2.9070 - val_acc: 0.1824
#
# Epoch 00007: val_loss improved from 2.91763 to 2.90697, saving model to Wehigts.hdf5
# Epoch 8/50
# 25/24 [==============================] - 10s 417ms/step - loss: 2.8963 - acc: 0.2187 - val_loss: 2.8964 - val_acc: 0.1913
#
# Epoch 00008: val_loss improved from 2.90697 to 2.89640, saving model to Wehigts.hdf5
# Epoch 9/50
# 25/24 [==============================] - 10s 418ms/step - loss: 2.8836 - acc: 0.2320 - val_loss: 2.8858 - val_acc: 0.1901
#
# Epoch 00009: val_loss improved from 2.89640 to 2.88579, saving model to Wehigts.hdf5
# Epoch 10/50
# 25/24 [==============================] - 11s 421ms/step - loss: 2.8725 - acc: 0.2342 - val_loss: 2.8751 - val_acc: 0.2143
#
# Epoch 00010: val_loss improved from 2.88579 to 2.87508, saving model to Wehigts.hdf5
# Epoch 11/50
# 25/24 [==============================] - 10s 416ms/step - loss: 2.8564 - acc: 0.2579 - val_loss: 2.8639 - val_acc: 0.2270
#
# Epoch 00011: val_loss improved from 2.87508 to 2.86388, saving model to Wehigts.hdf5
# Epoch 12/50
# 25/24 [==============================] - 10s 416ms/step - loss: 2.8459 - acc: 0.2783 - val_loss: 2.8532 - val_acc: 0.2513
#
# Epoch 00012: val_loss improved from 2.86388 to 2.85316, saving model to Wehigts.hdf5
# Epoch 13/50
# 25/24 [==============================] - 10s 416ms/step - loss: 2.8339 - acc: 0.3159 - val_loss: 2.8425 - val_acc: 0.2449
#
# Epoch 00013: val_loss improved from 2.85316 to 2.84247, saving model to Wehigts.hdf5
# Epoch 14/50
# 25/24 [==============================] - 10s 417ms/step - loss: 2.8216 - acc: 0.3209 - val_loss: 2.8322 - val_acc: 0.2462
#
# Epoch 00014: val_loss improved from 2.84247 to 2.83215, saving model to Wehigts.hdf5
# Epoch 15/50
# 25/24 [==============================] - 10s 417ms/step - loss: 2.8113 - acc: 0.3073 - val_loss: 2.8220 - val_acc: 0.2640
#
# Epoch 00015: val_loss improved from 2.83215 to 2.82201, saving model to Wehigts.hdf5
# Epoch 16/50
# 25/24 [==============================] - 10s 418ms/step - loss: 2.7998 - acc: 0.3549 - val_loss: 2.8120 - val_acc: 0.2679
#
# Epoch 00016: val_loss improved from 2.82201 to 2.81204, saving model to Wehigts.hdf5
# Epoch 17/50
# 25/24 [==============================] - 11s 421ms/step - loss: 2.7868 - acc: 0.3259 - val_loss: 2.8018 - val_acc: 0.2742
#
# Epoch 00017: val_loss improved from 2.81204 to 2.80184, saving model to Wehigts.hdf5
# Epoch 18/50
# 25/24 [==============================] - 10s 415ms/step - loss: 2.7782 - acc: 0.3347 - val_loss: 2.7922 - val_acc: 0.2666
#
# Epoch 00018: val_loss improved from 2.80184 to 2.79219, saving model to Wehigts.hdf5
# Epoch 19/50
# 25/24 [==============================] - 11s 422ms/step - loss: 2.7636 - acc: 0.3656 - val_loss: 2.7820 - val_acc: 0.2870
#
# Epoch 00019: val_loss improved from 2.79219 to 2.78201, saving model to Wehigts.hdf5
# Epoch 20/50
# 25/24 [==============================] - 11s 422ms/step - loss: 2.7530 - acc: 0.3697 - val_loss: 2.7724 - val_acc: 0.2934
#
# Epoch 00020: val_loss improved from 2.78201 to 2.77236, saving model to Wehigts.hdf5
# Epoch 21/50
# 25/24 [==============================] - 10s 417ms/step - loss: 2.7422 - acc: 0.3580 - val_loss: 2.7628 - val_acc: 0.3061
#
# Epoch 00021: val_loss improved from 2.77236 to 2.76282, saving model to Wehigts.hdf5
# Epoch 22/50
# 25/24 [==============================] - 10s 417ms/step - loss: 2.7284 - acc: 0.4246 - val_loss: 2.7532 - val_acc: 0.3023
#
# Epoch 00022: val_loss improved from 2.76282 to 2.75324, saving model to Wehigts.hdf5
# Epoch 23/50
# 25/24 [==============================] - 10s 419ms/step - loss: 2.7203 - acc: 0.3841 - val_loss: 2.7440 - val_acc: 0.3048
#
# Epoch 00023: val_loss improved from 2.75324 to 2.74397, saving model to Wehigts.hdf5
# Epoch 24/50
# 25/24 [==============================] - 10s 420ms/step - loss: 2.7096 - acc: 0.4158 - val_loss: 2.7347 - val_acc: 0.3023
#
# Epoch 00024: val_loss improved from 2.74397 to 2.73475, saving model to Wehigts.hdf5
# Epoch 25/50
# 25/24 [==============================] - 11s 420ms/step - loss: 2.7006 - acc: 0.4036 - val_loss: 2.7259 - val_acc: 0.3074
#
# Epoch 00025: val_loss improved from 2.73475 to 2.72590, saving model to Wehigts.hdf5
# Epoch 26/50
# 25/24 [==============================] - 10s 417ms/step - loss: 2.6861 - acc: 0.3999 - val_loss: 2.7172 - val_acc: 0.3048
#
# Epoch 00026: val_loss improved from 2.72590 to 2.71718, saving model to Wehigts.hdf5
# Epoch 27/50
# 25/24 [==============================] - 10s 416ms/step - loss: 2.6784 - acc: 0.4230 - val_loss: 2.7080 - val_acc: 0.3214
#
# Epoch 00027: val_loss improved from 2.71718 to 2.70801, saving model to Wehigts.hdf5
# Epoch 28/50
# 25/24 [==============================] - 10s 417ms/step - loss: 2.6669 - acc: 0.4341 - val_loss: 2.6991 - val_acc: 0.3291
#
# Epoch 00028: val_loss improved from 2.70801 to 2.69906, saving model to Wehigts.hdf5
# Epoch 29/50
# 25/24 [==============================] - 10s 420ms/step - loss: 2.6539 - acc: 0.4221 - val_loss: 2.6904 - val_acc: 0.3304
#
# Epoch 00029: val_loss improved from 2.69906 to 2.69036, saving model to Wehigts.hdf5
# Epoch 30/50
# 25/24 [==============================] - 11s 421ms/step - loss: 2.6458 - acc: 0.4316 - val_loss: 2.6814 - val_acc: 0.3291
#
# Epoch 00030: val_loss improved from 2.69036 to 2.68136, saving model to Wehigts.hdf5
# Epoch 31/50
# 25/24 [==============================] - 10s 416ms/step - loss: 2.6330 - acc: 0.4465 - val_loss: 2.6726 - val_acc: 0.3380
#
# Epoch 00031: val_loss improved from 2.68136 to 2.67255, saving model to Wehigts.hdf5
# Epoch 32/50
# 25/24 [==============================] - 10s 418ms/step - loss: 2.6226 - acc: 0.4516 - val_loss: 2.6640 - val_acc: 0.3240
#
# Epoch 00032: val_loss improved from 2.67255 to 2.66399, saving model to Wehigts.hdf5
# Epoch 33/50
# 25/24 [==============================] - 10s 418ms/step - loss: 2.6185 - acc: 0.4279 - val_loss: 2.6557 - val_acc: 0.3406
#
# Epoch 00033: val_loss improved from 2.66399 to 2.65567, saving model to Wehigts.hdf5
# Epoch 34/50
# 25/24 [==============================] - 10s 417ms/step - loss: 2.6002 - acc: 0.4549 - val_loss: 2.6472 - val_acc: 0.3508
#
# Epoch 00034: val_loss improved from 2.65567 to 2.64724, saving model to Wehigts.hdf5
# Epoch 35/50
# 25/24 [==============================] - 10s 418ms/step - loss: 2.5883 - acc: 0.4633 - val_loss: 2.6391 - val_acc: 0.3482
#
# Epoch 00035: val_loss improved from 2.64724 to 2.63910, saving model to Wehigts.hdf5
# Epoch 36/50
# 25/24 [==============================] - 11s 421ms/step - loss: 2.5756 - acc: 0.4733 - val_loss: 2.6304 - val_acc: 0.3469
#
# Epoch 00036: val_loss improved from 2.63910 to 2.63039, saving model to Wehigts.hdf5
# Epoch 37/50
# 25/24 [==============================] - 10s 416ms/step - loss: 2.5708 - acc: 0.4566 - val_loss: 2.6221 - val_acc: 0.3495
#
# Epoch 00037: val_loss improved from 2.63039 to 2.62210, saving model to Wehigts.hdf5
# Epoch 38/50
# 25/24 [==============================] - 11s 422ms/step - loss: 2.5608 - acc: 0.4679 - val_loss: 2.6142 - val_acc: 0.3418
#
# Epoch 00038: val_loss improved from 2.62210 to 2.61424, saving model to Wehigts.hdf5
# Epoch 39/50
# 25/24 [==============================] - 11s 420ms/step - loss: 2.5564 - acc: 0.4758 - val_loss: 2.6059 - val_acc: 0.3508
#
# Epoch 00039: val_loss improved from 2.61424 to 2.60587, saving model to Wehigts.hdf5
# Epoch 40/50
# 25/24 [==============================] - 10s 417ms/step - loss: 2.5437 - acc: 0.4815 - val_loss: 2.5977 - val_acc: 0.3520
#
# Epoch 00040: val_loss improved from 2.60587 to 2.59769, saving model to Wehigts.hdf5
# Epoch 41/50
# 25/24 [==============================] - 10s 415ms/step - loss: 2.5337 - acc: 0.5084 - val_loss: 2.5899 - val_acc: 0.3533
#
# Epoch 00041: val_loss improved from 2.59769 to 2.58985, saving model to Wehigts.hdf5
# Epoch 42/50
# 25/24 [==============================] - 10s 417ms/step - loss: 2.5232 - acc: 0.4755 - val_loss: 2.5818 - val_acc: 0.3520
#
# Epoch 00042: val_loss improved from 2.58985 to 2.58178, saving model to Wehigts.hdf5
# Epoch 43/50
# 25/24 [==============================] - 10s 420ms/step - loss: 2.5166 - acc: 0.4841 - val_loss: 2.5740 - val_acc: 0.3559
#
# Epoch 00043: val_loss improved from 2.58178 to 2.57397, saving model to Wehigts.hdf5
# Epoch 44/50
# 25/24 [==============================] - 10s 414ms/step - loss: 2.5045 - acc: 0.4902 - val_loss: 2.5666 - val_acc: 0.3597
#
# Epoch 00044: val_loss improved from 2.57397 to 2.56657, saving model to Wehigts.hdf5
# Epoch 45/50
# 25/24 [==============================] - 11s 420ms/step - loss: 2.5010 - acc: 0.4948 - val_loss: 2.5591 - val_acc: 0.3571
#
# Epoch 00045: val_loss improved from 2.56657 to 2.55912, saving model to Wehigts.hdf5
# Epoch 46/50
# 25/24 [==============================] - 10s 416ms/step - loss: 2.4837 - acc: 0.4998 - val_loss: 2.5515 - val_acc: 0.3622
#
# Epoch 00046: val_loss improved from 2.55912 to 2.55147, saving model to Wehigts.hdf5
# Epoch 47/50
# 25/24 [==============================] - 10s 417ms/step - loss: 2.4816 - acc: 0.4934 - val_loss: 2.5438 - val_acc: 0.3622
#
# Epoch 00047: val_loss improved from 2.55147 to 2.54380, saving model to Wehigts.hdf5
# Epoch 48/50
# 25/24 [==============================] - 11s 422ms/step - loss: 2.4703 - acc: 0.4920 - val_loss: 2.5361 - val_acc: 0.3699
#
# Epoch 00048: val_loss improved from 2.54380 to 2.53613, saving model to Wehigts.hdf5
# Epoch 49/50
# 25/24 [==============================] - 11s 422ms/step - loss: 2.4647 - acc: 0.5124 - val_loss: 2.5290 - val_acc: 0.3661
#
# Epoch 00049: val_loss improved from 2.53613 to 2.52905, saving model to Wehigts.hdf5
# Epoch 50/50
# 25/24 [==============================] - 10s 420ms/step - loss: 2.4540 - acc: 0.4982 - val_loss: 2.5220 - val_acc: 0.3635
#
# Epoch 00050: val_loss improved from 2.52905 to 2.52195, saving model to Wehigts.hdf5

# %%
#Usar Checpoint mejor de ejecución
model.load_weights(checkpoint_path)
for j, layer in enumerate(model1.layers):
    layer.trainable = True

#Compile y ejecutar de nuevo
#rms = RMSprop(lr=0.0001, rho=0.9, epsilon=None, decay=0.0)
#adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-6, amsgrad=False)

model.compile(loss='categorical_crossentropy',
              optimizer=rms,
              metrics=['accuracy'])
    
  
model.summary()

checkpoint_path = "Wehigts_final.hdf5"
checkpointer = ModelCheckpoint(filepath=checkpoint_path, verbose=1, save_best_only=True)

## TRAINING with DA and LRA
history=model.fit_generator(datagen.flow(x_train, y_train,batch_size=batch_size),
                            steps_per_epoch=len(x_train) / batch_size, 
                            epochs=epochs,
                            validation_data=(x_test, y_test),
                            callbacks=[checkpointer],
                            verbose=1)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           (None, 250, 250, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 250, 250, 64) 1792        input_14[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 250, 250, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 125, 125, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 125, 125, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 125, 125, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 62, 62, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 62, 62, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 62, 62, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 62, 62, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 31, 31, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 31, 31, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 31, 31, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 31, 31, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 15, 15, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 15, 15, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 15, 15, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 15, 15, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 15, 15, 512)  0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 15, 15, 512)  0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# outer_product (Lambda)          (None, 262144)       0           dropout_27[0][0]
#                                                                  dropout_28[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 20)           5242900     outer_product[0][0]
# ==================================================================================================
# Total params: 19,957,588
# Trainable params: 19,957,588
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
# 25/24 [==============================] - 21s 859ms/step - loss: 3.0114 - acc: 0.0650 - val_loss: 2.9961 - val_acc: 0.0510
#
# Epoch 00001: val_loss improved from inf to 2.99607, saving model to Wehigts_final.hdf5
# Epoch 2/50
# 25/24 [==============================] - 20s 788ms/step - loss: 2.9964 - acc: 0.0450 - val_loss: 2.9957 - val_acc: 0.0587
#
# Epoch 00002: val_loss improved from 2.99607 to 2.99573, saving model to Wehigts_final.hdf5
# Epoch 3/50
# 25/24 [==============================] - 21s 834ms/step - loss: 2.9962 - acc: 0.0525 - val_loss: 2.9953 - val_acc: 0.0587
#
# Epoch 00003: val_loss improved from 2.99573 to 2.99527, saving model to Wehigts_final.hdf5
# Epoch 4/50
# 25/24 [==============================] - 20s 814ms/step - loss: 3.0156 - acc: 0.0505 - val_loss: 2.9941 - val_acc: 0.0536
#
# Epoch 00004: val_loss improved from 2.99527 to 2.99408, saving model to Wehigts_final.hdf5
# Epoch 5/50
# 25/24 [==============================] - 20s 814ms/step - loss: 2.9978 - acc: 0.0472 - val_loss: 2.9922 - val_acc: 0.0587
#
# Epoch 00005: val_loss improved from 2.99408 to 2.99217, saving model to Wehigts_final.hdf5
# Epoch 6/50
# 25/24 [==============================] - 21s 833ms/step - loss: 2.9975 - acc: 0.0549 - val_loss: 2.9945 - val_acc: 0.0561
#
# Epoch 00006: val_loss did not improve
# Epoch 7/50
# 25/24 [==============================] - 20s 814ms/step - loss: 2.9956 - acc: 0.0572 - val_loss: 2.9935 - val_acc: 0.0561
#
# Epoch 00007: val_loss did not improve
# Epoch 8/50
# 25/24 [==============================] - 20s 812ms/step - loss: 2.9949 - acc: 0.0567 - val_loss: 2.9927 - val_acc: 0.0561
#
# Epoch 00008: val_loss did not improve
# Epoch 9/50
# 25/24 [==============================] - 20s 812ms/step - loss: 2.9944 - acc: 0.0530 - val_loss: 2.9904 - val_acc: 0.0548
#
# Epoch 00009: val_loss improved from 2.99217 to 2.99038, saving model to Wehigts_final.hdf5
# Epoch 10/50
# 25/24 [==============================] - 20s 813ms/step - loss: 2.9876 - acc: 0.0525 - val_loss: 3.1091 - val_acc: 0.0689
#
# Epoch 00010: val_loss did not improve
# Epoch 11/50
# 25/24 [==============================] - 20s 808ms/step - loss: 2.9921 - acc: 0.0580 - val_loss: 2.9898 - val_acc: 0.0599
#
# Epoch 00011: val_loss improved from 2.99038 to 2.98983, saving model to Wehigts_final.hdf5
# Epoch 12/50
# 25/24 [==============================] - 20s 810ms/step - loss: 2.9547 - acc: 0.0652 - val_loss: 2.9476 - val_acc: 0.0663
#
# Epoch 00012: val_loss improved from 2.98983 to 2.94756, saving model to Wehigts_final.hdf5
# Epoch 13/50
# 25/24 [==============================] - 20s 809ms/step - loss: 2.9428 - acc: 0.0968 - val_loss: 2.8809 - val_acc: 0.0957
#
# Epoch 00013: val_loss improved from 2.94756 to 2.88089, saving model to Wehigts_final.hdf5
# Epoch 14/50
# 25/24 [==============================] - 20s 807ms/step - loss: 2.8662 - acc: 0.1040 - val_loss: 3.0135 - val_acc: 0.1033
#
# Epoch 00014: val_loss did not improve
# Epoch 15/50
# 25/24 [==============================] - 20s 810ms/step - loss: 2.8732 - acc: 0.1171 - val_loss: 2.8714 - val_acc: 0.1097
#
# Epoch 00015: val_loss improved from 2.88089 to 2.87136, saving model to Wehigts_final.hdf5
# Epoch 16/50
# 25/24 [==============================] - 20s 805ms/step - loss: 2.8265 - acc: 0.1137 - val_loss: 2.9842 - val_acc: 0.0714
#
# Epoch 00016: val_loss did not improve
# Epoch 17/50
# 25/24 [==============================] - 20s 807ms/step - loss: 2.8254 - acc: 0.1127 - val_loss: 2.8087 - val_acc: 0.1224
#
# Epoch 00017: val_loss improved from 2.87136 to 2.80866, saving model to Wehigts_final.hdf5
# Epoch 18/50
# 25/24 [==============================] - 20s 804ms/step - loss: 2.7938 - acc: 0.1210 - val_loss: 2.7922 - val_acc: 0.1339
#
# Epoch 00018: val_loss improved from 2.80866 to 2.79220, saving model to Wehigts_final.hdf5
# Epoch 19/50
# 25/24 [==============================] - 20s 808ms/step - loss: 2.7807 - acc: 0.1471 - val_loss: 2.7687 - val_acc: 0.1352
#
# Epoch 00019: val_loss improved from 2.79220 to 2.76873, saving model to Wehigts_final.hdf5
# Epoch 20/50
# 25/24 [==============================] - 20s 804ms/step - loss: 2.7423 - acc: 0.1391 - val_loss: 2.8023 - val_acc: 0.1186
#
# Epoch 00020: val_loss did not improve
# Epoch 21/50
# 25/24 [==============================] - 20s 807ms/step - loss: 2.7188 - acc: 0.1557 - val_loss: 2.8591 - val_acc: 0.1314
#
# Epoch 00021: val_loss did not improve
# Epoch 22/50
# 25/24 [==============================] - 20s 808ms/step - loss: 2.7264 - acc: 0.1377 - val_loss: 2.7732 - val_acc: 0.1352
#
# Epoch 00022: val_loss did not improve
# Epoch 23/50
# 25/24 [==============================] - 20s 806ms/step - loss: 2.6705 - acc: 0.1652 - val_loss: 2.7679 - val_acc: 0.1684
#
# Epoch 00023: val_loss improved from 2.76873 to 2.76790, saving model to Wehigts_final.hdf5
# Epoch 24/50
# 25/24 [==============================] - 20s 805ms/step - loss: 2.6630 - acc: 0.1662 - val_loss: 2.7157 - val_acc: 0.1518
#
# Epoch 00024: val_loss improved from 2.76790 to 2.71567, saving model to Wehigts_final.hdf5
# Epoch 25/50
# 25/24 [==============================] - 20s 801ms/step - loss: 2.6557 - acc: 0.1682 - val_loss: 2.6933 - val_acc: 0.1798
#
# Epoch 00025: val_loss improved from 2.71567 to 2.69329, saving model to Wehigts_final.hdf5
# Epoch 26/50
# 25/24 [==============================] - 20s 801ms/step - loss: 2.6386 - acc: 0.1910 - val_loss: 2.6772 - val_acc: 0.1633
#
# Epoch 00026: val_loss improved from 2.69329 to 2.67719, saving model to Wehigts_final.hdf5
# Epoch 27/50
# 25/24 [==============================] - 20s 804ms/step - loss: 2.5836 - acc: 0.1946 - val_loss: 2.6681 - val_acc: 0.1747
#
# Epoch 00027: val_loss improved from 2.67719 to 2.66814, saving model to Wehigts_final.hdf5
# Epoch 28/50
# 25/24 [==============================] - 20s 820ms/step - loss: 2.5279 - acc: 0.2160 - val_loss: 2.5988 - val_acc: 0.2168
#
# Epoch 00028: val_loss improved from 2.66814 to 2.59884, saving model to Wehigts_final.hdf5
# Epoch 29/50
# 25/24 [==============================] - 20s 801ms/step - loss: 2.4913 - acc: 0.2220 - val_loss: 2.5805 - val_acc: 0.1888
#
# Epoch 00029: val_loss improved from 2.59884 to 2.58049, saving model to Wehigts_final.hdf5
# Epoch 30/50
# 25/24 [==============================] - 20s 804ms/step - loss: 2.3573 - acc: 0.2650 - val_loss: 2.6766 - val_acc: 0.2003
#
# Epoch 00030: val_loss did not improve
# Epoch 31/50
# 25/24 [==============================] - 20s 805ms/step - loss: 2.3097 - acc: 0.2495 - val_loss: 2.3613 - val_acc: 0.2832
#
# Epoch 00031: val_loss improved from 2.58049 to 2.36130, saving model to Wehigts_final.hdf5
# Epoch 32/50
# 25/24 [==============================] - 20s 803ms/step - loss: 2.1624 - acc: 0.3176 - val_loss: 2.3614 - val_acc: 0.2449
#
# Epoch 00032: val_loss did not improve
# Epoch 33/50
# 25/24 [==============================] - 20s 805ms/step - loss: 2.0744 - acc: 0.3184 - val_loss: 2.3882 - val_acc: 0.2462
#
# Epoch 00033: val_loss did not improve
# Epoch 34/50
# 25/24 [==============================] - 20s 803ms/step - loss: 1.9454 - acc: 0.3558 - val_loss: 2.0977 - val_acc: 0.2832
#
# Epoch 00034: val_loss improved from 2.36130 to 2.09770, saving model to Wehigts_final.hdf5
# Epoch 35/50
# 25/24 [==============================] - 20s 802ms/step - loss: 1.9026 - acc: 0.3727 - val_loss: 1.8339 - val_acc: 0.3878
#
# Epoch 00035: val_loss improved from 2.09770 to 1.83393, saving model to Wehigts_final.hdf5
# Epoch 36/50
# 25/24 [==============================] - 20s 802ms/step - loss: 1.7153 - acc: 0.4249 - val_loss: 1.7907 - val_acc: 0.3699
#
# Epoch 00036: val_loss improved from 1.83393 to 1.79068, saving model to Wehigts_final.hdf5
# Epoch 37/50
# 25/24 [==============================] - 20s 802ms/step - loss: 1.7274 - acc: 0.4035 - val_loss: 1.8799 - val_acc: 0.3418
#
# Epoch 00037: val_loss did not improve
# Epoch 38/50
# 25/24 [==============================] - 20s 803ms/step - loss: 1.5356 - acc: 0.4588 - val_loss: 1.5847 - val_acc: 0.4605
#
# Epoch 00038: val_loss improved from 1.79068 to 1.58471, saving model to Wehigts_final.hdf5
# Epoch 39/50
# 25/24 [==============================] - 20s 801ms/step - loss: 1.4205 - acc: 0.5021 - val_loss: 1.9417 - val_acc: 0.3316
#
# Epoch 00039: val_loss did not improve
# Epoch 40/50
# 25/24 [==============================] - 20s 802ms/step - loss: 1.4003 - acc: 0.5151 - val_loss: 1.4928 - val_acc: 0.5166
#
# Epoch 00040: val_loss improved from 1.58471 to 1.49282, saving model to Wehigts_final.hdf5
# Epoch 41/50
# 25/24 [==============================] - 20s 803ms/step - loss: 1.2244 - acc: 0.5942 - val_loss: 1.8110 - val_acc: 0.4107
#
# Epoch 00041: val_loss did not improve
# Epoch 42/50
# 25/24 [==============================] - 20s 802ms/step - loss: 1.2007 - acc: 0.5915 - val_loss: 1.4070 - val_acc: 0.5077
#
# Epoch 00042: val_loss improved from 1.49282 to 1.40700, saving model to Wehigts_final.hdf5
# Epoch 43/50
# 25/24 [==============================] - 20s 803ms/step - loss: 1.0850 - acc: 0.6386 - val_loss: 1.2595 - val_acc: 0.5676
#
# Epoch 00043: val_loss improved from 1.40700 to 1.25947, saving model to Wehigts_final.hdf5
# Epoch 44/50
# 25/24 [==============================] - 20s 801ms/step - loss: 1.0476 - acc: 0.6480 - val_loss: 1.2726 - val_acc: 0.5842
#
# Epoch 00044: val_loss did not improve
# Epoch 45/50
# 25/24 [==============================] - 20s 802ms/step - loss: 0.9349 - acc: 0.7191 - val_loss: 1.7265 - val_acc: 0.4311
#
# Epoch 00045: val_loss did not improve
# Epoch 46/50
# 25/24 [==============================] - 20s 803ms/step - loss: 0.8959 - acc: 0.6992 - val_loss: 1.1192 - val_acc: 0.6084
#
# Epoch 00046: val_loss improved from 1.25947 to 1.11924, saving model to Wehigts_final.hdf5
# Epoch 47/50
# 25/24 [==============================] - 20s 801ms/step - loss: 0.8108 - acc: 0.7430 - val_loss: 1.6166 - val_acc: 0.4656
#
# Epoch 00047: val_loss did not improve
# Epoch 48/50
# 25/24 [==============================] - 20s 804ms/step - loss: 0.7352 - acc: 0.7738 - val_loss: 1.1849 - val_acc: 0.5880
#
# Epoch 00048: val_loss did not improve
# Epoch 49/50
# 25/24 [==============================] - 20s 802ms/step - loss: 0.8142 - acc: 0.7535 - val_loss: 1.1136 - val_acc: 0.6301
#
# Epoch 00049: val_loss improved from 1.11924 to 1.11359, saving model to Wehigts_final.hdf5
# Epoch 50/50
# 25/24 [==============================] - 20s 799ms/step - loss: 0.6978 - acc: 0.7605 - val_loss: 1.2461 - val_acc: 0.5727
#
# Epoch 00050: val_loss did not improve
